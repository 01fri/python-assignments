# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %pip install Google-Colab-Transfer
# Out:
# Collecting Google-Colab-Transfer
#   Downloading Google_Colab_Transfer-0.1.6-py3-none-any.whl (7.0 kB)
# Installing collected packages: Google-Colab-Transfer
# Successfully installed Google-Colab-Transfer-0.1.6

# %%
# !apt-get install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts imagemagick
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# 0 upgraded, 23 newly installed, 0 to remove and 40 not upgraded.
# Need to get 18.4 MB of archives.
# After this operation, 66.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.11 [60.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [1,619 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [294 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.14 [5,092 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [2,265 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [51.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6.q16 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [423 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [14.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-text all 3.5.27.1-8ubuntu0.4 [49.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre21 amd64 3.5.27.1-8ubuntu0.4 [561 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3-extra amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [62.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnetpbm10 amd64 2:10.0-15.3build1 [58.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 netpbm amd64 2:10.0-15.3build1 [1,017 kB]
# Fetched 18.4 MB in 0s (44.9 MB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 160837 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../01-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../02-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.11_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../03-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../04-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../05-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../06-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../07-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../08-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../09-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../10-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.14_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../11-libgs9_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../12-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../13-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../14-imagemagick-6.q16_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../15-imagemagick_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking imagemagick (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../16-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../17-libdjvulibre-text_3.5.27.1-8ubuntu0.4_all.deb ...
# Unpacking libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../18-libdjvulibre21_3.5.27.1-8ubuntu0.4_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../19-libwmf0.2-7_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Selecting previously unselected package libmagickcore-6.q16-3-extra:amd64.
# Preparing to unpack .../20-libmagickcore-6.q16-3-extra_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libnetpbm10.
# Preparing to unpack .../21-libnetpbm10_2%3a10.0-15.3build1_amd64.deb ...
# Unpacking libnetpbm10 (2:10.0-15.3build1) ...
# Selecting previously unselected package netpbm.
# Preparing to unpack .../22-netpbm_2%3a10.0-15.3build1_amd64.deb ...
# Unpacking netpbm (2:10.0-15.3build1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up poppler-data (0.4.8-2) ...
# Setting up libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Setting up libnetpbm10 (2:10.0-15.3build1) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up netpbm (2:10.0-15.3build1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Setting up libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up imagemagick (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
import colab_transfer

gd = colab_transfer.get_path_to_home_of_google_drive()
lm = colab_transfer.get_path_to_home_of_local_machine()

colab_transfer.mount_google_drive()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada.git
# Out:
# fatal: destination path 'stylegan2-ada' already exists and is not an empty directory.

# %%
# !mogrify -resize !256x256 /content/drive/MyDrive/Python21/imgs/*.jpg

# %%
# !python stylegan2-ada/dataset_tool.py create_from_images /content/drive/MyDrive/Python21/dataset/ /content/drive/MyDrive/Python21/imgs/
# Out:
# Loading images from "/content/drive/MyDrive/Python21/imgs/"
# Creating dataset "/content/drive/MyDrive/Python21/dataset/"
# stylegan2-ada/dataset_tool.py:96: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 1760 images.
# Traceback (most recent call last):
#   File "stylegan2-ada/dataset_tool.py", line 993, in <module>
#     execute_cmdline(sys.argv)
#   File "stylegan2-ada/dataset_tool.py", line 988, in execute_cmdline
#     func(**vars(args))
#   File "stylegan2-ada/dataset_tool.py", line 672, in create_from_images
#     img = np.asarray(PIL.Image.open(image_filenames[order[idx]]))
#   File "/usr/local/lib/python3.7/dist-packages/PIL/Image.py", line 2852, in open
#     prefix = fp.read(16)
# KeyboardInterrupt

# %%
# !python ./stylegan2-ada/train.py \
--outdir='/content/drive/MyDrive/Python21/output' \
--snap=6 --data='/content/drive/MyDrive/Python21/dataset' --mirror=true \
--metrics=none \
--cfg=auto \
--kimg=3000 \
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x56403a674000 @  0x7f5189834001 0x7f5186a7754f 0x7f5186ac7b58 0x7f5186acbb17 0x7f5186b6a203 0x564032c690a4 0x564032c68da0 0x564032cdd868 0x564032cd8235 0x564032c6afec 0x564032cabbc9 0x564032ca8ac4 0x564032c698a9 0x564032cddb0a 0x564032cd7c35 0x564032ba9e2c 0x564032cda318 0x564032cd7c35 0x564032ba9e2c 0x564032cda318 0x564032cd8235 0x564032ba9e2c 0x564032cda318 0x564032c6a65a 0x564032cd8b0e 0x564032cd7c35 0x564032cd7933 0x564032da1402 0x564032da177d 0x564032da1626 0x564032d79313
# tcmalloc: large alloc 4294967296 bytes == 0x56413a676000 @  0x7f51898321e7 0x7f5186a7746e 0x7f5186ac7c7b 0x7f5186ac835f 0x7f5186b6a103 0x564032c690a4 0x564032c68da0 0x564032cdd868 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032c6a65a 0x564032cd8b0e 0x564032cd7c35 0x564032c6a73a 0x564032cdcf40 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032cd8235 0x564032c6afec 0x564032cabbc9 0x564032ca8ac4 0x564032c698a9 0x564032cddb0a
# tcmalloc: large alloc 4294967296 bytes == 0x56423b9c8000 @  0x7f51898321e7 0x7f5186a7746e 0x7f5186ac7c7b 0x7f5186ac835f 0x7f5143439235 0x7f5142dbc792 0x7f5142dbcd42 0x7f5142d75aee 0x564032c68f97 0x564032c68da0 0x564032cdd2f9 0x564032c6a65a 0x564032cd8d67 0x564032cd7dcc 0x564032ba9eb1 0x564032cda318 0x564032cd7c35 0x564032c6a73a 0x564032cd8d67 0x564032cd8235 0x564032c6a73a 0x564032cd8d67 0x564032c6a65a 0x564032cd8d67 0x564032cd7c35 0x564032c6add1 0x564032c6b1f1 0x564032cda318 0x564032cd7c35 0x564032c6a73a 0x564032cd8b0e
#
# Training options:
# {
#   "G_args": {
#     "func_name": "training.networks.G_main",
#     "fmap_base": 8192,
#     "fmap_max": 512,
#     "mapping_layers": 2,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "D_args": {
#     "func_name": "training.networks.D_main",
#     "mbstd_group_size": 4,
#     "fmap_base": 8192,
#     "fmap_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.0025
#   },
#   "D_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.0025
#   },
#   "loss_args": {
#     "func_name": "training.loss.stylegan2",
#     "r1_gamma": 0.8192
#   },
#   "augment_args": {
#     "class_name": "training.augment.AdaptiveAugment",
#     "tune_heuristic": "rt",
#     "tune_target": 0.6,
#     "apply_func": "training.augment.augment_pipeline",
#     "apply_args": {
#       "xflip": 1,
#       "rotate90": 1,
#       "xint": 1,
#       "scale": 1,
#       "rotate": 1,
#       "aniso": 1,
#       "xfrac": 1,
#       "brightness": 1,
#       "contrast": 1,
#       "lumaflip": 1,
#       "hue": 1,
#       "saturation": 1
#     }
#   },
#   "num_gpus": 1,
#   "image_snapshot_ticks": 6,
#   "network_snapshot_ticks": 6,
#   "train_dataset_args": {
#     "path": "/content/drive/MyDrive/Python21/dataset",
#     "max_label_size": 0,
#     "resolution": 256,
#     "mirror_augment": true
#   },
#   "metric_arg_list": [],
#   "metric_dataset_args": {
#     "path": "/content/drive/MyDrive/Python21/dataset",
#     "max_label_size": 0,
#     "resolution": 256,
#     "mirror_augment": true
#   },
#   "total_kimg": 3000,
#   "minibatch_size": 16,
#   "minibatch_gpu": 16,
#   "G_smoothing_kimg": 5.0,
#   "G_smoothing_rampup": 0.05,
#   "run_dir": "/content/drive/MyDrive/Python21/output/00004-dataset-mirror-auto1-kimg3000"
# }
#
# Output directory:  /content/drive/MyDrive/Python21/output/00004-dataset-mirror-auto1-kimg3000
# Training data:     /content/drive/MyDrive/Python21/dataset
# Training length:   3000 kimg
# Resolution:        256
# Number of GPUs:    1
#
# Creating output directory...
# Loading training set...
# tcmalloc: large alloc 4294967296 bytes == 0x56403a674000 @  0x7f5189834001 0x7f5186a7754f 0x7f5186ac7b58 0x7f5186acbb17 0x7f5186b6a203 0x564032c690a4 0x564032c68da0 0x564032cdd868 0x564032cd8235 0x564032c6afec 0x564032cabbc9 0x564032ca8ac4 0x564032c698a9 0x564032cddb0a 0x564032cd7c35 0x564032ba9e2c 0x564032cda318 0x564032cd7c35 0x564032ba9e2c 0x564032cda318 0x564032cd8235 0x564032ba9e2c 0x564032cda318 0x564032c6a65a 0x564032cd8b0e 0x564032cd7c35 0x564032cd7933 0x564032da1402 0x564032da177d 0x564032da1626 0x564032d79313
# tcmalloc: large alloc 4294967296 bytes == 0x56433b9c8000 @  0x7f51898321e7 0x7f5186a7746e 0x7f5186ac7c7b 0x7f5186ac835f 0x7f5186b6a103 0x564032c690a4 0x564032c68da0 0x564032cdd868 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032c6a65a 0x564032cd8b0e 0x564032cd7c35 0x564032c6a73a 0x564032cdcf40 0x564032cd7c35 0x564032c6a73a 0x564032cd993b 0x564032cd8235 0x564032c6afec 0x564032cabbc9 0x564032ca8ac4 0x564032c698a9 0x564032cddb0a
# tcmalloc: large alloc 4294967296 bytes == 0x56433b9c8000 @  0x7f51898321e7 0x7f5186a7746e 0x7f5186ac7c7b 0x7f5186ac835f 0x7f5143439235 0x7f5142dbc792 0x7f5142dbcd42 0x7f5142d75aee 0x564032c68f97 0x564032c68da0 0x564032cdd2f9 0x564032c6a65a 0x564032cd8d67 0x564032cd7dcc 0x564032ba9eb1 0x564032cda318 0x564032cd7c35 0x564032c6a73a 0x564032cd8d67 0x564032cd8235 0x564032c6a73a 0x564032cd8d67 0x564032c6a65a 0x564032cd8d67 0x564032cd7c35 0x564032c6add1 0x564032c6b1f1 0x564032cda318 0x564032cd7c35 0x564032c6a73a 0x564032cd8b0e
# Image shape: [3, 256, 256]
# Label shape: [0]
#
# Constructing networks...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 14, 512)        -
# dlatent_avg                   -         (512,)              -
# Truncation/Lerp               -         (?, 14, 512)        -
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up    1442561   (?, 256, 64, 64)    (3, 3, 512, 256)
# G_synthesis/64x64/Conv1       721409    (?, 256, 64, 64)    (3, 3, 256, 256)
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
# G_synthesis/64x64/ToRGB       132099    (?, 3, 64, 64)      (1, 1, 256, 3)
# G_synthesis/128x128/Conv0_up  426369    (?, 128, 128, 128)  (3, 3, 256, 128)
# G_synthesis/128x128/Conv1     213249    (?, 128, 128, 128)  (3, 3, 128, 128)
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
# G_synthesis/128x128/ToRGB     66051     (?, 3, 128, 128)    (1, 1, 128, 3)
# G_synthesis/256x256/Conv0_up  139457    (?, 64, 256, 256)   (3, 3, 128, 64)
# G_synthesis/256x256/Conv1     69761     (?, 64, 256, 256)   (3, 3, 64, 64)
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
# G_synthesis/256x256/ToRGB     33027     (?, 3, 256, 256)    (1, 1, 64, 3)
# ---                           ---       ---                 ---
# Total                         23191522
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 256, 256)    -
# labels_in            -         (?, 0)              -
# 256x256/FromRGB      256       (?, 64, 256, 256)   (1, 1, 3, 64)
# 256x256/Conv0        36928     (?, 64, 256, 256)   (3, 3, 64, 64)
# 256x256/Conv1_down   73856     (?, 128, 128, 128)  (3, 3, 64, 128)
# 256x256/Skip         8192      (?, 128, 128, 128)  (1, 1, 64, 128)
# 128x128/Conv0        147584    (?, 128, 128, 128)  (3, 3, 128, 128)
# 128x128/Conv1_down   295168    (?, 256, 64, 64)    (3, 3, 128, 256)
# 128x128/Skip         32768     (?, 256, 64, 64)    (1, 1, 128, 256)
# 64x64/Conv0          590080    (?, 256, 64, 64)    (3, 3, 256, 256)
# 64x64/Conv1_down     1180160   (?, 512, 32, 32)    (3, 3, 256, 512)
# 64x64/Skip           131072    (?, 512, 32, 32)    (1, 1, 256, 512)
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
# 8x8/Skip             262144    (?, 512, 4, 4)      (1, 1, 512, 512)
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
# Output               513       (?, 1)              (512, 1)
# ---                  ---       ---                 ---
# Total                24001089
#
# Exporting sample images...
# Replicating networks across 1 GPUs...
# Initializing augmentations...
# Setting up optimizers...
# Constructing training graph...
# Finalizing training ops...
# Initializing metrics...
# Training for 3000 kimg...
#
# tick 0     kimg 0.1      time 1m 29s       sec/tick 16.5    sec/kimg 257.38  maintenance 72.7   gpumem 7.3   augment 0.000
# tick 1     kimg 4.1      time 3m 36s       sec/tick 98.9    sec/kimg 24.53   maintenance 28.0   gpumem 7.3   augment 0.006
# tick 2     kimg 8.1      time 5m 14s       sec/tick 98.2    sec/kimg 24.36   maintenance 0.0    gpumem 7.3   augment 0.013
# tick 3     kimg 12.2     time 6m 52s       sec/tick 98.2    sec/kimg 24.35   maintenance 0.0    gpumem 7.3   augment 0.017
# tick 4     kimg 16.2     time 8m 31s       sec/tick 98.5    sec/kimg 24.42   maintenance 0.0    gpumem 7.3   augment 0.022
# tick 5     kimg 20.2     time 10m 09s      sec/tick 98.3    sec/kimg 24.37   maintenance 0.0    gpumem 7.3   augment 0.028
# tick 6     kimg 24.3     time 11m 48s      sec/tick 98.6    sec/kimg 24.45   maintenance 0.0    gpumem 7.3   augment 0.034
# tick 7     kimg 28.3     time 13m 39s      sec/tick 99.4    sec/kimg 24.64   maintenance 12.1   gpumem 7.3   augment 0.040
# tick 8     kimg 32.3     time 15m 18s      sec/tick 98.6    sec/kimg 24.46   maintenance 0.1    gpumem 7.3   augment 0.045
# tick 9     kimg 36.4     time 16m 57s      sec/tick 98.7    sec/kimg 24.48   maintenance 0.0    gpumem 7.3   augment 0.052
# tick 10    kimg 40.4     time 18m 36s      sec/tick 98.9    sec/kimg 24.53   maintenance 0.0    gpumem 7.3   augment 0.056
# tick 11    kimg 44.4     time 20m 14s      sec/tick 98.8    sec/kimg 24.51   maintenance 0.0    gpumem 7.3   augment 0.062
# tick 12    kimg 48.4     time 21m 53s      sec/tick 98.9    sec/kimg 24.53   maintenance 0.0    gpumem 7.3   augment 0.067
# tick 13    kimg 52.5     time 23m 47s      sec/tick 99.1    sec/kimg 24.59   maintenance 14.3   gpumem 7.3   augment 0.073
# tick 14    kimg 56.5     time 25m 26s      sec/tick 99.1    sec/kimg 24.58   maintenance 0.0    gpumem 7.3   augment 0.077
# tick 15    kimg 60.5     time 27m 05s      sec/tick 99.0    sec/kimg 24.55   maintenance 0.0    gpumem 7.3   augment 0.082
# tick 16    kimg 64.6     time 28m 44s      sec/tick 98.9    sec/kimg 24.52   maintenance 0.0    gpumem 7.3   augment 0.087
# tick 17    kimg 68.6     time 30m 23s      sec/tick 99.0    sec/kimg 24.55   maintenance 0.0    gpumem 7.3   augment 0.092
# tick 18    kimg 72.6     time 32m 02s      sec/tick 98.9    sec/kimg 24.53   maintenance 0.0    gpumem 7.3   augment 0.097
# tick 19    kimg 76.7     time 34m 00s      sec/tick 99.5    sec/kimg 24.68   maintenance 18.6   gpumem 7.3   augment 0.102
# tick 20    kimg 80.7     time 35m 39s      sec/tick 99.4    sec/kimg 24.65   maintenance 0.0    gpumem 7.3   augment 0.108
# tick 21    kimg 84.7     time 37m 18s      sec/tick 99.0    sec/kimg 24.56   maintenance 0.0    gpumem 7.3   augment 0.113
# tick 22    kimg 88.8     time 38m 57s      sec/tick 99.2    sec/kimg 24.60   maintenance 0.0    gpumem 7.3   augment 0.118
# tick 23    kimg 92.8     time 40m 37s      sec/tick 99.1    sec/kimg 24.58   maintenance 0.0    gpumem 7.3   augment 0.122
# tick 24    kimg 96.8     time 42m 16s      sec/tick 99.2    sec/kimg 24.59   maintenance 0.0    gpumem 7.3   augment 0.127
# tick 25    kimg 100.9    time 44m 13s      sec/tick 99.5    sec/kimg 24.69   maintenance 17.6   gpumem 7.3   augment 0.130
# tick 26    kimg 104.9    time 45m 52s      sec/tick 99.2    sec/kimg 24.61   maintenance 0.0    gpumem 7.3   augment 0.133
# tick 27    kimg 108.9    time 47m 32s      sec/tick 99.4    sec/kimg 24.65   maintenance 0.0    gpumem 7.3   augment 0.135
# tick 28    kimg 113.0    time 49m 11s      sec/tick 99.4    sec/kimg 24.66   maintenance 0.0    gpumem 7.3   augment 0.139
# tick 29    kimg 117.0    time 50m 50s      sec/tick 99.1    sec/kimg 24.57   maintenance 0.0    gpumem 7.3   augment 0.142
# tick 30    kimg 121.0    time 52m 29s      sec/tick 99.3    sec/kimg 24.64   maintenance 0.0    gpumem 7.3   augment 0.147
# tick 31    kimg 125.1    time 54m 24s      sec/tick 100.1   sec/kimg 24.83   maintenance 14.8   gpumem 7.3   augment 0.151
# tick 32    kimg 129.1    time 56m 04s      sec/tick 99.4    sec/kimg 24.65   maintenance 0.1    gpumem 7.3   augment 0.154
# tick 33    kimg 133.1    time 57m 43s      sec/tick 99.4    sec/kimg 24.65   maintenance 0.0    gpumem 7.3   augment 0.156
# tick 34    kimg 137.2    time 59m 23s      sec/tick 99.5    sec/kimg 24.68   maintenance 0.0    gpumem 7.3   augment 0.157
# tick 35    kimg 141.2    time 1h 01m 02s   sec/tick 99.5    sec/kimg 24.67   maintenance 0.0    gpumem 7.3   augment 0.161
# tick 36    kimg 145.2    time 1h 02m 42s   sec/tick 99.5    sec/kimg 24.67   maintenance 0.0    gpumem 7.3   augment 0.163
# tick 37    kimg 149.2    time 1h 04m 36s   sec/tick 100.0   sec/kimg 24.79   maintenance 14.5   gpumem 7.3   augment 0.167
# tick 38    kimg 153.3    time 1h 06m 16s   sec/tick 99.7    sec/kimg 24.73   maintenance 0.0    gpumem 7.3   augment 0.171
# tick 39    kimg 157.3    time 1h 07m 56s   sec/tick 99.6    sec/kimg 24.70   maintenance 0.0    gpumem 7.3   augment 0.177
# tick 40    kimg 161.3    time 1h 09m 35s   sec/tick 99.6    sec/kimg 24.70   maintenance 0.0    gpumem 7.3   augment 0.181
# tick 41    kimg 165.4    time 1h 11m 15s   sec/tick 99.7    sec/kimg 24.73   maintenance 0.0    gpumem 7.3   augment 0.186
# tick 42    kimg 169.4    time 1h 12m 54s   sec/tick 99.5    sec/kimg 24.67   maintenance 0.0    gpumem 7.3   augment 0.189
# tick 43    kimg 173.4    time 1h 14m 49s   sec/tick 100.0   sec/kimg 24.79   maintenance 14.8   gpumem 7.3   augment 0.193
# tick 44    kimg 177.5    time 1h 16m 29s   sec/tick 99.9    sec/kimg 24.76   maintenance 0.0    gpumem 7.3   augment 0.196
# tick 45    kimg 181.5    time 1h 18m 09s   sec/tick 99.5    sec/kimg 24.69   maintenance 0.0    gpumem 7.3   augment 0.200
# tick 46    kimg 185.5    time 1h 19m 48s   sec/tick 99.7    sec/kimg 24.72   maintenance 0.0    gpumem 7.3   augment 0.205
# tick 47    kimg 189.6    time 1h 21m 28s   sec/tick 99.6    sec/kimg 24.69   maintenance 0.0    gpumem 7.3   augment 0.210
# tick 48    kimg 193.6    time 1h 23m 08s   sec/tick 99.9    sec/kimg 24.78   maintenance 0.0    gpumem 7.3   augment 0.214
# tick 49    kimg 197.6    time 1h 25m 02s   sec/tick 99.7    sec/kimg 24.74   maintenance 14.7   gpumem 7.3   augment 0.218
# tick 50    kimg 201.7    time 1h 26m 42s   sec/tick 99.8    sec/kimg 24.75   maintenance 0.0    gpumem 7.3   augment 0.223
# tick 51    kimg 205.7    time 1h 28m 22s   sec/tick 100.0   sec/kimg 24.80   maintenance 0.0    gpumem 7.3   augment 0.227
# tick 52    kimg 209.7    time 1h 30m 02s   sec/tick 99.7    sec/kimg 24.72   maintenance 0.0    gpumem 7.3   augment 0.229
# tick 53    kimg 213.8    time 1h 31m 41s   sec/tick 99.6    sec/kimg 24.70   maintenance 0.0    gpumem 7.3   augment 0.233
# tick 54    kimg 217.8    time 1h 33m 21s   sec/tick 99.8    sec/kimg 24.75   maintenance 0.0    gpumem 7.3   augment 0.237
# tick 55    kimg 221.8    time 1h 35m 16s   sec/tick 100.7   sec/kimg 24.96   maintenance 14.6   gpumem 7.3   augment 0.242
# tick 56    kimg 225.9    time 1h 36m 56s   sec/tick 99.9    sec/kimg 24.77   maintenance 0.0    gpumem 7.3   augment 0.248
# tick 57    kimg 229.9    time 1h 38m 36s   sec/tick 99.9    sec/kimg 24.78   maintenance 0.0    gpumem 7.3   augment 0.253
# tick 58    kimg 233.9    time 1h 40m 16s   sec/tick 100.1   sec/kimg 24.83   maintenance 0.0    gpumem 7.3   augment 0.259
# tick 59    kimg 238.0    time 1h 41m 56s   sec/tick 99.8    sec/kimg 24.75   maintenance 0.0    gpumem 7.3   augment 0.263
# tick 60    kimg 242.0    time 1h 43m 36s   sec/tick 99.9    sec/kimg 24.79   maintenance 0.0    gpumem 7.3   augment 0.268
# tick 61    kimg 246.0    time 1h 45m 31s   sec/tick 100.1   sec/kimg 24.83   maintenance 14.8   gpumem 7.3   augment 0.273
# tick 62    kimg 250.0    time 1h 47m 11s   sec/tick 100.1   sec/kimg 24.82   maintenance 0.0    gpumem 7.3   augment 0.276
# tick 63    kimg 254.1    time 1h 48m 51s   sec/tick 100.0   sec/kimg 24.81   maintenance 0.0    gpumem 7.3   augment 0.280
# tick 64    kimg 258.1    time 1h 50m 31s   sec/tick 99.9    sec/kimg 24.78   maintenance 0.0    gpumem 7.3   augment 0.283
# tick 65    kimg 262.1    time 1h 52m 11s   sec/tick 100.0   sec/kimg 24.79   maintenance 0.0    gpumem 7.3   augment 0.286
# tick 66    kimg 266.2    time 1h 53m 51s   sec/tick 100.0   sec/kimg 24.79   maintenance 0.0    gpumem 7.3   augment 0.290
# tick 67    kimg 270.2    time 1h 55m 47s   sec/tick 100.1   sec/kimg 24.83   maintenance 15.5   gpumem 7.3   augment 0.294

# %%
# !python stylegan2-ada/train.py \
--outdir='/content/drive/MyDrive/Python21/output' \
--snap=6 \
--data='/content/drive/MyDrive/Python21/dataset' \
--mirror=true \
--metrics=none \
--cfg=auto \
--kimg=5000 \
--resume='/content/drive/MyDrive/Python21/output/00002-dataset-mirror-auto1-kimg5000-resumecustom-freezed10/network-snapshot-000048.pkl' \
--freezed=10

# %%
# !python stylegan2-ada/generate.py --outdir=/content/drive/MyDrive/Python21/output/results --trunc=1 --seeds=300-505 --network="/content/drive/MyDrive/Python21/output/00004-dataset-mirror-auto1-kimg3000/network-snapshot-000193.pkl"
# Out:
# Loading networks from "/content/drive/MyDrive/Python21/output/00002-dataset-mirror-auto1-kimg5000-resumecustom-freezed10/network-snapshot-000048.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 300 (0/206) ...
# Generating image for seed 301 (1/206) ...
# Generating image for seed 302 (2/206) ...
# Generating image for seed 303 (3/206) ...
# Generating image for seed 304 (4/206) ...
# Generating image for seed 305 (5/206) ...
# Generating image for seed 306 (6/206) ...
# Generating image for seed 307 (7/206) ...
# Generating image for seed 308 (8/206) ...
# Generating image for seed 309 (9/206) ...
# Generating image for seed 310 (10/206) ...
# Generating image for seed 311 (11/206) ...
# Generating image for seed 312 (12/206) ...
# Generating image for seed 313 (13/206) ...
# Generating image for seed 314 (14/206) ...
# Generating image for seed 315 (15/206) ...
# Generating image for seed 316 (16/206) ...
# Generating image for seed 317 (17/206) ...
# Generating image for seed 318 (18/206) ...
# Generating image for seed 319 (19/206) ...
# Generating image for seed 320 (20/206) ...
# Generating image for seed 321 (21/206) ...
# Generating image for seed 322 (22/206) ...
# Generating image for seed 323 (23/206) ...
# Generating image for seed 324 (24/206) ...
# Generating image for seed 325 (25/206) ...
# Generating image for seed 326 (26/206) ...
# Generating image for seed 327 (27/206) ...
# Generating image for seed 328 (28/206) ...
# Generating image for seed 329 (29/206) ...
# Generating image for seed 330 (30/206) ...
# Generating image for seed 331 (31/206) ...
# Generating image for seed 332 (32/206) ...
# Generating image for seed 333 (33/206) ...
# Generating image for seed 334 (34/206) ...
# Generating image for seed 335 (35/206) ...
# Generating image for seed 336 (36/206) ...
# Generating image for seed 337 (37/206) ...
# Generating image for seed 338 (38/206) ...
# Generating image for seed 339 (39/206) ...
# Generating image for seed 340 (40/206) ...
# Generating image for seed 341 (41/206) ...
# Generating image for seed 342 (42/206) ...
# Generating image for seed 343 (43/206) ...
# Generating image for seed 344 (44/206) ...
# Generating image for seed 345 (45/206) ...
# Generating image for seed 346 (46/206) ...
# Generating image for seed 347 (47/206) ...
# Generating image for seed 348 (48/206) ...
# Generating image for seed 349 (49/206) ...
# Generating image for seed 350 (50/206) ...
# Generating image for seed 351 (51/206) ...
# Generating image for seed 352 (52/206) ...
# Generating image for seed 353 (53/206) ...
# Generating image for seed 354 (54/206) ...
# Generating image for seed 355 (55/206) ...
# Generating image for seed 356 (56/206) ...
# Generating image for seed 357 (57/206) ...
# Generating image for seed 358 (58/206) ...
# Generating image for seed 359 (59/206) ...
# Generating image for seed 360 (60/206) ...
# Generating image for seed 361 (61/206) ...
# Generating image for seed 362 (62/206) ...
# Generating image for seed 363 (63/206) ...
# Generating image for seed 364 (64/206) ...
# Generating image for seed 365 (65/206) ...
# Generating image for seed 366 (66/206) ...
# Generating image for seed 367 (67/206) ...
# Generating image for seed 368 (68/206) ...
# Generating image for seed 369 (69/206) ...
# Generating image for seed 370 (70/206) ...
# Generating image for seed 371 (71/206) ...
# Generating image for seed 372 (72/206) ...
# Generating image for seed 373 (73/206) ...
# Generating image for seed 374 (74/206) ...
# Generating image for seed 375 (75/206) ...
# Generating image for seed 376 (76/206) ...
# Generating image for seed 377 (77/206) ...
# Generating image for seed 378 (78/206) ...
# Generating image for seed 379 (79/206) ...
# Generating image for seed 380 (80/206) ...
# Generating image for seed 381 (81/206) ...
# Generating image for seed 382 (82/206) ...
# Generating image for seed 383 (83/206) ...
# Generating image for seed 384 (84/206) ...
# Generating image for seed 385 (85/206) ...
# Generating image for seed 386 (86/206) ...
# Generating image for seed 387 (87/206) ...
# Generating image for seed 388 (88/206) ...
# Generating image for seed 389 (89/206) ...
# Generating image for seed 390 (90/206) ...
# Generating image for seed 391 (91/206) ...
# Generating image for seed 392 (92/206) ...
# Generating image for seed 393 (93/206) ...
# Generating image for seed 394 (94/206) ...
# Generating image for seed 395 (95/206) ...
# Generating image for seed 396 (96/206) ...
# Generating image for seed 397 (97/206) ...
# Generating image for seed 398 (98/206) ...
# Generating image for seed 399 (99/206) ...
# Generating image for seed 400 (100/206) ...
# Generating image for seed 401 (101/206) ...
# Generating image for seed 402 (102/206) ...
# Generating image for seed 403 (103/206) ...
# Generating image for seed 404 (104/206) ...
# Generating image for seed 405 (105/206) ...
# Generating image for seed 406 (106/206) ...
# Generating image for seed 407 (107/206) ...
# Generating image for seed 408 (108/206) ...
# Generating image for seed 409 (109/206) ...
# Generating image for seed 410 (110/206) ...
# Generating image for seed 411 (111/206) ...
# Generating image for seed 412 (112/206) ...
# Generating image for seed 413 (113/206) ...
# Generating image for seed 414 (114/206) ...
# Generating image for seed 415 (115/206) ...
# Generating image for seed 416 (116/206) ...
# Generating image for seed 417 (117/206) ...
# Generating image for seed 418 (118/206) ...
# Generating image for seed 419 (119/206) ...
# Generating image for seed 420 (120/206) ...
# Generating image for seed 421 (121/206) ...
# Generating image for seed 422 (122/206) ...
# Generating image for seed 423 (123/206) ...
# Generating image for seed 424 (124/206) ...
# Generating image for seed 425 (125/206) ...
# Generating image for seed 426 (126/206) ...
# Generating image for seed 427 (127/206) ...
# Generating image for seed 428 (128/206) ...
# Generating image for seed 429 (129/206) ...
# Generating image for seed 430 (130/206) ...
# Generating image for seed 431 (131/206) ...
# Generating image for seed 432 (132/206) ...
# Generating image for seed 433 (133/206) ...
# Generating image for seed 434 (134/206) ...
# Generating image for seed 435 (135/206) ...
# Generating image for seed 436 (136/206) ...
# Generating image for seed 437 (137/206) ...
# Generating image for seed 438 (138/206) ...
# Generating image for seed 439 (139/206) ...
# Generating image for seed 440 (140/206) ...
# Generating image for seed 441 (141/206) ...
# Generating image for seed 442 (142/206) ...
# Generating image for seed 443 (143/206) ...
# Generating image for seed 444 (144/206) ...
# Generating image for seed 445 (145/206) ...
# Generating image for seed 446 (146/206) ...
# Generating image for seed 447 (147/206) ...
# Generating image for seed 448 (148/206) ...
# Generating image for seed 449 (149/206) ...
# Generating image for seed 450 (150/206) ...
# Generating image for seed 451 (151/206) ...
# Generating image for seed 452 (152/206) ...
# Generating image for seed 453 (153/206) ...
# Generating image for seed 454 (154/206) ...
# Generating image for seed 455 (155/206) ...
# Generating image for seed 456 (156/206) ...
# Generating image for seed 457 (157/206) ...
# Generating image for seed 458 (158/206) ...
# Generating image for seed 459 (159/206) ...
# Generating image for seed 460 (160/206) ...
# Generating image for seed 461 (161/206) ...
# Generating image for seed 462 (162/206) ...
# Generating image for seed 463 (163/206) ...
# Generating image for seed 464 (164/206) ...
# Generating image for seed 465 (165/206) ...
# Generating image for seed 466 (166/206) ...
# Generating image for seed 467 (167/206) ...
# Generating image for seed 468 (168/206) ...
# Generating image for seed 469 (169/206) ...
# Generating image for seed 470 (170/206) ...
# Generating image for seed 471 (171/206) ...
# Generating image for seed 472 (172/206) ...
# Generating image for seed 473 (173/206) ...
# Generating image for seed 474 (174/206) ...
# Generating image for seed 475 (175/206) ...
# Generating image for seed 476 (176/206) ...
# Generating image for seed 477 (177/206) ...
# Generating image for seed 478 (178/206) ...
# Generating image for seed 479 (179/206) ...
# Generating image for seed 480 (180/206) ...
# Generating image for seed 481 (181/206) ...
# Generating image for seed 482 (182/206) ...
# Generating image for seed 483 (183/206) ...
# Generating image for seed 484 (184/206) ...
# Generating image for seed 485 (185/206) ...
# Generating image for seed 486 (186/206) ...
# Generating image for seed 487 (187/206) ...
# Generating image for seed 488 (188/206) ...
# Generating image for seed 489 (189/206) ...
# Generating image for seed 490 (190/206) ...
# Generating image for seed 491 (191/206) ...
# Generating image for seed 492 (192/206) ...
# Generating image for seed 493 (193/206) ...
# Generating image for seed 494 (194/206) ...
# Generating image for seed 495 (195/206) ...
# Generating image for seed 496 (196/206) ...
# Generating image for seed 497 (197/206) ...
# Generating image for seed 498 (198/206) ...
# Generating image for seed 499 (199/206) ...
# Generating image for seed 500 (200/206) ...
# Generating image for seed 501 (201/206) ...
# Generating image for seed 502 (202/206) ...
# Generating image for seed 503 (203/206) ...
# Generating image for seed 504 (204/206) ...
# Generating image for seed 505 (205/206) ...
