# %%
# %tensorflow_version 1.x
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x #If you are using Google Colab`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# %pip install Google-Colab-Transfer

# %%
# !apt-get install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
# ...

# %%
import colab_transfer

gd = colab_transfer.get_path_to_home_of_google_drive()
lm = colab_transfer.get_path_to_home_of_local_machine()

colab_transfer.mount_google_drive()
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada.git
# Out:
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 71, done.
# remote: Total 71 (delta 0), reused 0 (delta 0), pack-reused 71
# Unpacking objects: 100% (71/71), done.

# %%
pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/  stylegan2-ada/

# %%
# %cd stylegan2-ada/
# Out:
# /content/stylegan2-ada

# %%
pwd
# Out:
# '/content/stylegan2-ada'

# %%
cd ../
# Out:
# /content

# %%
# %mkdir basefordataset
# %cd basefordataset

# %mkdir category1
# %cd category1
# Out:
# /content/basefordataset
# /content/basefordataset/category1

# %%
pwd
# Out:
# '/content/basefordataset/category1'

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
 print('User uploaded file "{name}" with length {length} bytes'.format(
     name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-68499a0d-b53e-407b-bd6b-683d8ccac300" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68499a0d-b53e-407b-bd6b-683d8ccac300">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving porcelain96.jpg to porcelain96.jpg
# Saving porcelain97.jpg to porcelain97.jpg
# Saving porcelain98.jpg to porcelain98.jpg
# Saving porcelain99.jpg to porcelain99.jpg
# Saving porcelain100.jpg to porcelain100.jpg
# Saving porcelain101.jpg to porcelain101.jpg
# Saving porcelain102.jpg to porcelain102.jpg
# Saving porcelain103.jpg to porcelain103.jpg
# Saving porcelain104.jpg to porcelain104.jpg
# Saving porcelain105.jpg to porcelain105.jpg
# Saving porcelain106.jpg to porcelain106.jpg
# Saving porcelain107.jpg to porcelain107.jpg
# ...

# %%
pwd
# Out:
# '/content/basefordataset/category1'

# %%
cd ../../
# Out:
# /content

# %%
pwd
# Out:
# '/content'

# %%
# !mogrify -resize !256x256 basefordataset/category1/*.jpg

# %%
pwd
# Out:
# '/content'

# %%
# !python stylegan2-ada/dataset_tool.py create_from_images ./dataset ./basefordataset/category1/
# Out:
# Loading images from "./basefordataset/category1/"
# Creating dataset "./dataset"
# stylegan2-ada/dataset_tool.py:96: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 2287 images.

# %%
# !tar -czvf dataset.tar.gz ./dataset/
# Out:
# ./dataset/
# ./dataset/dataset-r04.tfrecords
# ./dataset/dataset-r03.tfrecords
# ./dataset/dataset-r07.tfrecords
# ./dataset/dataset-r06.tfrecords
# ./dataset/dataset-r08.tfrecords
# ./dataset/dataset-r02.tfrecords
# ./dataset/dataset-r05.tfrecords

# %%
colab_transfer.copy_file(
   file_name="dataset.tar.gz",
   source="./",
   destination="./drive/My Drive/Datasets/",
)
# Out:
# File ./drive/My Drive/Datasets/dataset.tar.gz already exists. Copy skipped.

# %%
colab_transfer.copy_file(
   file_name="dataset.tar.gz",
   source="./drive/My Drive/Datasets/",
   destination="./stylegan2-ada/Datasets/",
)
# Out:
# Copying ./drive/My Drive/Datasets/dataset.tar.gz to ./stylegan2-ada/Datasets/dataset.tar.gz

# %%
# !tar -C ./stylegan2-ada/Datasets/ -xvf ./stylegan2-ada/Datasets/dataset.tar.gz
# Out:
# ./dataset/
# ./dataset/dataset-r02.tfrecords
# ./dataset/dataset-r03.tfrecords
# ./dataset/dataset-r05.tfrecords
# ./dataset/dataset-r08.tfrecords
# ./dataset/dataset-r07.tfrecords
# ./dataset/dataset-r06.tfrecords
# ./dataset/dataset-r04.tfrecords

# %%
# %cd content/
# Out:
# [Errno 2] No such file or directory: 'content/'
# /content

# %%
# !python ./stylegan2-ada/train.py \
--outdir='OutputDir' \
--snap=6 --data='./dataset' --mirror=true \
--metrics=none \
--cfg=auto \
--kimg=360 \
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x55b776c10000 @  0x7fc217daf001 0x7fc214ff254f 0x7fc215042b58 0x7fc215046b17 0x7fc2150e5203 0x55b76f3610e4 0x55b76f360de0 0x55b76f3d56f5 0x55b76f3cfe0d 0x55b76f36302c 0x55b76f3a3d39 0x55b76f3a0c84 0x55b76f3618e9 0x55b76f3d5ade 0x55b76f3cfb0e 0x55b76f2a1e2b 0x55b76f3d21e6 0x55b76f3cfb0e 0x55b76f2a1e2b 0x55b76f3d21e6 0x55b76f3cfe0d 0x55b76f2a1e2b 0x55b76f3d21e6 0x55b76f36269a 0x55b76f3d0a45 0x55b76f3cfb0e 0x55b76f3cf813 0x55b76f499592 0x55b76f49990d 0x55b76f4997b6 0x55b76f471103
# ...

# %%
# !python stylegan2-ada/train.py \
--outdir='/content/Output' \
--snap=6 \
--data='/content/dataset' \
--mirror=true \
--metrics=none \
--cfg=auto \
--kimg=200 \
--resume='/content/OutputDir/00001-dataset-mirror-auto1-kimg100-resumecustom-freezed10/network-snapshot-000000.pkl' \
--freezed=10
# Out:
# python3: can't open file 'stylegan2-ada/train.py': [Errno 2] No such file or directory

# %%
# !python stylegan2-ada/train.py \
--outdir='OutputDir' \
--snap=6 \
--data='/content/dataset' \
--mirror=true \
--metrics=none \
--cfg=auto \
--kimg=500 \
--resume='/content/OutputDir/00003-dataset-mirror-auto1-kimg500-resumecustom-freezed10/network-snapshot-000048.pkl' \
--freezed=10
# Out:
# python3: can't open file 'stylegan2-ada/train.py': [Errno 2] No such file or directory

# %%
pwd
# Out:
# '/content'

# %%
# !python stylegan2-ada/generate.py --outdir=out --trunc=1 --seeds=0-500 --network="/content/OutputDir/00003-dataset-mirror-auto1-kimg500-resumecustom-freezed10/network-snapshot-000048.pkl"
# Out:
# Loading networks from "/content/OutputDir/00003-dataset-mirror-auto1-kimg500-resumecustom-freezed10/network-snapshot-000048.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 0 (0/501) ...
# Generating image for seed 1 (1/501) ...
# Generating image for seed 2 (2/501) ...
# Generating image for seed 3 (3/501) ...
# Generating image for seed 4 (4/501) ...
# Generating image for seed 5 (5/501) ...
# Generating image for seed 6 (6/501) ...
# Generating image for seed 7 (7/501) ...
# Generating image for seed 8 (8/501) ...
# Generating image for seed 9 (9/501) ...
# Generating image for seed 10 (10/501) ...
# Generating image for seed 11 (11/501) ...
# Generating image for seed 12 (12/501) ...
# Generating image for seed 13 (13/501) ...
# Generating image for seed 14 (14/501) ...
# Generating image for seed 15 (15/501) ...
# Generating image for seed 16 (16/501) ...
# ...
